# %% [markdown]
# ### Домашнее задание №4
# ### Непрерывные случайные величины. Функция распределения и плотность распределения вероятностей. Равномерное и нормальное распределение. Центральная предельная теорема

# %% [markdown]
# 1.	Случайная непрерывная величина A имеет равномерное распределение на промежутке (200, 800].
# Найдите ее среднее значение и дисперсию.

# %% [markdown]
# #### M(А) = 499.99(9)                  # математическое ожидание (среднее значение)

# %% [markdown]
# #### D(A) = 29999.99(9) # дисперсия

# %% [markdown]
# 2.	О случайной непрерывной равномерно распределенной величине B известно, что ее дисперсия равна 0.2.
# Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5?
# Если да, найдите ее.

# %% [markdown]
# #### Правая граница величины B = 2.049193338

# %% [markdown]
# #### Среднее значение величины B = 1.274596669

# %% [markdown]
# 3.	Непрерывная случайная величина X распределена нормально и задана плотностью распределения
# f(x) = (1 / (4 * sqrt(2*pi))) * (exp(-(x+2)**2) / 32).
# Найдите:
# а). M(X)
# б). D(X)
# в). std(X) (среднее квадратичное отклонение)

# %% [markdown]
# #### а) M(X) = -2

# %% [markdown]
# #### б) D(X) = 16

# %% [markdown]
# #### в) std(X) = 4

# %% [markdown]
# 4.	Рост взрослого населения города X имеет нормальное распределение.
# Причем, средний рост равен 174 см, а среднее квадратичное отклонение равно 8 см.
# Какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
# а). больше 182 см
# б). больше 190 см
# в). от 166 см до 190 см
# г). от 166 см до 182 см
# д). от 158 см до 190 см
# е). не выше 150 см или не ниже 190 см
# ё). не выше 150 см или не ниже 198 см
# ж). ниже 166 см.

# %% [markdown]
# а) P (больше 182 см (+1σ)):

# %% [markdown]
# #### 0.1587

# %% [markdown]
# б) P (больше 190 см (+2σ)):

# %% [markdown]
# #### 0.0228

# %% [markdown]
# в) P (от 166 до 190 см (от -1σ до +2σ)) = 0.3413 + 0.4772 =

# %% [markdown]
# #### 0.8185

# %% [markdown]
# г) P (от 166 до 182 см (от -1σ до +1σ)) = 0.3413 + 0.3413 =

# %% [markdown]
# #### 0.6826 (по таблице нормального распределения) или 0.68 (по правилу трех сигм)

# %% [markdown]
# д) P (от 158 до 182 см (от -2σ до +1σ)) = 0.4772 + 0.3413 =

# %% [markdown]
# #### 0.8185

# %% [markdown]
# е) P (не выше 150 см или не ниже 190 см (<= -3σ и >= +2σ)) = 0.0013 + 0.0228 =

# %% [markdown]
# #### 0.0241

# %% [markdown]
# ё)  P (не выше 150 см или не ниже 198 см (<= -3σ и >= +3σ)) = 0.0013 + 0.0013 =

# %% [markdown]
# #### 0.0026 (по таблице нормального распределения) или 0.0028 (по правилу трех сигм)

# %% [markdown]
# ж) P (ниже 166 см (до -1σ)):

# %% [markdown]
# #### 0.1587

# %% [markdown]
# 5.	На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см, от
# математического ожидания роста в популяции, в которой M(X) = 178 см и D(X) = 25 кв.см?

# %% [markdown]
# #### При нормальном распределении и std(X) = 5 см отклонение роста 190 см от 178 см составляет +2,4σ (сигм)
